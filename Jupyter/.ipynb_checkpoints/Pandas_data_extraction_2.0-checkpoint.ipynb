# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# ## What is Pandas
#
# - Pandas is built on top of Python
# - Two main data structures:
#     - `DataFrame`
#     - `Series`
#
# A `DataFrame` is like a spreadsheet, a two-dimensional labelled data structure with columns of potentially different types.
# A `Series` is a single column of a `DataFrame`, similar to an Excel column. But we can deal with a series as an object in its own right, especially when we have a single series of data. Notice that, unlike Python's built-in list, we can refer to items in a series by a `label`.
#
#
# ### Key Differences Between Pandas and Excel
#
# | Feature                 | Pandas                                                      | Excel                                                       |
# |-------------------------|-------------------------------------------------------------|-------------------------------------------------------------|
# | Data Structure          | DataFrame, Series                                           | Worksheet, Range                                            |
# | Handling Large Datasets | Designed for efficient manipulation of large data sets      | Can become slow with very large datasets                    |
# | Programming             | Requires Python programming                                 | Mostly GUI-based with formulas/VBA for automation           |
# | Data Analysis           | Extensive built-in functions for statistical analysis       | Basic built-in functions, external add-ins for advanced use |
# | Data Visualization      | Integrated with Matplotlib, Seaborn for plots and graphs    | Built-in charting tools, less customizable                  |
# | File Formats            | Supports multiple formats (CSV, Excel, JSON, SQL, etc.)     | Primarily Excel formats (XLSX, XLS), limited external formats|
# | Real-time Data          | Can easily handle real-time data with updates               | Not designed for real-time data processing                  |
# | Collaboration           | Code and results easily shared via notebooks (e.g., Jupyter)| Direct file sharing, issues with version control            |

# %% [markdown]
# ### Transitioning from Excel to Pandas
#
# - **Reading and Writing Data**: In pandas, reading from and writing to various file formats is straightforward. For example, `pd.read_csv('file.csv')` to read a CSV file into a DataFrame, akin to opening a CSV with Excel.
#
# - **Data Manipulation**: Unlike Excel, where data manipulation is done through formulas or VBA scripts, pandas uses Python code. Filtering, sorting, and aggregating data through method calls on DataFrame objects.
#
# - **Automation and Reproducibility**: Pandas, with Python, allows for the automation of data processing scripts, making repetitive tasks more efficient and less prone to error compared to manual operations in Excel.

# %% [markdown]
# ## Section 1: Installing and importing Pandas

# %%
# Install Pandas package using magic command if you have not already done that
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in .\.venv\Lib\site-packages (3.0.0)
# Requirement already satisfied: numpy>=2.3.3 in .\.venv\Lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# To use the Pandas package, run the following code
# pd is the conventional alias for pandas

import pandas as pd

#Let's check the pandas version that has been installed
print("Installed version : ", pd.__version__)
# Out:
# Installed version :  3.0.0

# %% [markdown]
# ## Section 2: Creating Series and DataFrames

# %%
# Create a panda's Series from a list
# Notice that the indices are displayed for the Series, but not the list

list_nums = [0.25, 0.5, 0.75, 1.0, -7, -6.5]
s_nums = pd.Series(list_nums)
print("print the original list")
print(list_nums)
print("print the new Series")
print(s_nums)
# Out:
# print the original list
# [0.25, 0.5, 0.75, 1.0, -7, -6.5]
# print the new Series
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# 4   -7.00
# 5   -6.50
# dtype: float64

# %%
# Create  a panda's DataFrame from a dictionary
# Example 1
dict_population = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}

df_population = pd.Series(dict_population)
print("print the original dictionary")
print(dict_population)
print("print the new DataFrame")
print(df_population)
# Out:
# print the original dictionary
# {'California': 38332521, 'Texas': 26448193, 'New York': 19651127, 'Florida': 19552860, 'Illinois': 12882135}
# print the new DataFrame
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
# Example 2

data = {
    'Date': ['2024-02-01', '2024-02-01', '2024-02-02', '2024-02-02'],
    'Product': ['Product A', 'Product B', 'Product A', 'Product B'],
    'Quantity': [10, 15, 5, 7],
    'Price': [20, 25, 20, 25]
}

df_products = pd.DataFrame(data)
df_products
# Out:
#          Date    Product  Quantity  Price
# 0  2024-02-01  Product A        10     20
# 1  2024-02-01  Product B        15     25
# 2  2024-02-02  Product A         5     20
# 3  2024-02-02  Product B         7     25

# %%
# Mostly, we will be bringing data from external sources such as excel files, csv files, json files, databases etc.
# Here is an example of loading data from a .csv file
# Copy the attached intro_data.csv file on Blackboard to the same folder as this notebook

df_intro = pd.read_csv('intro_data.csv')

# Note that this results in a DataFrame
type(df_intro)
# Out:
# pandas.DataFrame

# %% [markdown]
# ## Section 3: Exploring the dataset

# %%
# head() loads the top 5 rows by default
df_intro.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
# tail() loads the bottom 5 rows by default
df_intro.tail()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
# You can override the detault number of records loaded in the head(), tail() function

print("top")
print(df_intro.head(15))

print("bottom")
print(df_intro.tail(3))
# Out:
# top
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# bottom
#     Duration          Date  Pulse  Maxpulse  Calories
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
# Use the info() to get an idea about the size of the dataset, data types recognized and null(empty) values

df_intro.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     str
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), str(1)
# memory usage: 1.7 KB

# %%
# Use the describe() to get an idea about the statistical distribution of the data

print(df_intro.describe())

# You can also call this function on a specific column only

print(df_intro['Duration'].describe())
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000
# count     32.000000
# mean      68.437500
# std       70.039591
# min       30.000000
# 25%       60.000000
# 50%       60.000000
# 75%       60.000000
# max      450.000000
# Name: Duration, dtype: float64

# %%
# Example 2
# Using the describe() on df_products
# Notice that results are returned for numeric columns only
df_products.describe()
# Out:
#         Quantity      Price
# count   4.000000   4.000000
# mean    9.250000  22.500000
# std     4.349329   2.886751
# min     5.000000  20.000000
# 25%     6.500000  20.000000
# 50%     8.500000  22.500000
# 75%    11.250000  25.000000
# max    15.000000  25.000000

# %% [markdown]
# #### Understanding the index
#
# The index refers to the labels of the rows. In this example, pandas automatically created an index.

# %%
# you do not need to understand this cell it is only for styling purposes
from IPython.display import display, HTML

display(HTML(f'<span style="color: red; font-weight: bold">{df_products.index}</span>'))

styled_df = df_products.style.set_table_styles([
    {'selector': 'th.row_heading', 'props': [('color', 'red')]}
]) # you don't need to understand this line - it is just to highlight the index.

styled_df
# Out:
# <span style="color: red; font-weight: bold">RangeIndex(start=0, stop=4, step=1)</span>
# <style type="text/css">
# #T_0f340 th.row_heading {
#   color: red;
# }
# </style>
# <table id="T_0f340">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f340_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_0f340_level0_col1" class="col_heading level0 col1" >Product</th>
#       <th id="T_0f340_level0_col2" class="col_heading level0 col2" >Quantity</th>
#       <th id="T_0f340_level0_col3" class="col_heading level0 col3" >Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f340_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f340_row0_col0" class="data row0 col0" >2024-02-01</td>
#       <td id="T_0f340_row0_col1" class="data row0 col1" >Product A</td>
#       <td id="T_0f340_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_0f340_row0_col3" class="data row0 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_0f340_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f340_row1_col0" class="data row1 col0" >2024-02-01</td>
#       <td id="T_0f340_row1_col1" class="data row1 col1" >Product B</td>
#       <td id="T_0f340_row1_col2" class="data row1 col2" >15</td>
#       <td id="T_0f340_row1_col3" class="data row1 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_0f340_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0f340_row2_col0" class="data row2 col0" >2024-02-02</td>
#       <td id="T_0f340_row2_col1" class="data row2 col1" >Product A</td>
#       <td id="T_0f340_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_0f340_row2_col3" class="data row2 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_0f340_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0f340_row3_col0" class="data row3 col0" >2024-02-02</td>
#       <td id="T_0f340_row3_col1" class="data row3 col1" >Product B</td>
#       <td id="T_0f340_row3_col2" class="data row3 col2" >7</td>
#       <td id="T_0f340_row3_col3" class="data row3 col3" >25</td>
#     </tr>
#   </tbody>
# </table>

# %%
from IPython.display import display, HTML

display(HTML(f'<span style="color: red; font-weight: bold">{df_products.index}</span>'))

# Custom indices can be assigned to Series/DataFrames

data = {'Name': ['John', 'Alice', 'Bob'], 'Age': [25, 30, 22]}
df_people = pd.DataFrame(data)

print("DF with original indices")

styled_df_people = df_people.style.set_table_styles([
    {'selector': 'th.row_heading', 'props': [('color', 'red')]}
]) # you don't need to understand this line - it is just to highlight the index.

styled_df_people
# Out:
# <span style="color: red; font-weight: bold">RangeIndex(start=0, stop=4, step=1)</span>
# DF with original indices
# <style type="text/css">
# #T_9eb30 th.row_heading {
#   color: red;
# }
# </style>
# <table id="T_9eb30">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9eb30_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_9eb30_level0_col1" class="col_heading level0 col1" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9eb30_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9eb30_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_9eb30_row0_col1" class="data row0 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9eb30_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9eb30_row1_col0" class="data row1 col0" >Alice</td>
#       <td id="T_9eb30_row1_col1" class="data row1 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_9eb30_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9eb30_row2_col0" class="data row2 col0" >Bob</td>
#       <td id="T_9eb30_row2_col1" class="data row2 col1" >22</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Set the 'Name' column as the new index
df = pd.DataFrame(data)
df_new_people = df.set_index('Name')

styled_df_new_people = df_new_people.style.set_table_styles([
    {'selector': 'th.row_heading', 'props': [('color', 'red')]}
]) # you don't need to understand this line - it is just to highlight the index.

styled_df_new_people

# To modify the original DataFrame in place, use inplace=True
# df.set_index('Name', inplace=True) 
print("DF with modified indices")
styled_df_new_people
# Out:
# DF with modified indices
# <style type="text/css">
# #T_20745 th.row_heading {
#   color: red;
# }
# </style>
# <table id="T_20745">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20745_level0_col0" class="col_heading level0 col0" >Age</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20745_level0_row0" class="row_heading level0 row0" >John</th>
#       <td id="T_20745_row0_col0" class="data row0 col0" >25</td>
#     </tr>
#     <tr>
#       <th id="T_20745_level0_row1" class="row_heading level0 row1" >Alice</th>
#       <td id="T_20745_row1_col0" class="data row1 col0" >30</td>
#     </tr>
#     <tr>
#       <th id="T_20745_level0_row2" class="row_heading level0 row2" >Bob</th>
#       <td id="T_20745_row2_col0" class="data row2 col0" >22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Exercise
# ## Processing and extracting data from csv/Excel using pandas
#
# While pandas is famous for its programmatic data analytics. For some tasks, it is significantly easier to use than Excel.
# Here we are going to combine a series of files in `csv` and then create basic pivot tables.
#
# Portions of this section are based on:
#
# [Extracting and pivoting data in pandas](https://www.youtube.com/watch?v=NqcPLp8a4Eg)

# %%
# Constants
DATA_DIR = 'data/'
PATTERN = '*.csv'

# %% [markdown]
# ### Preparation
# 1. Download the [files used in the video](https://github.com/jhnwr/auto-reporting)
# 2. Store them in a subdirectory called `data/`
# 3. Use the code below as a starting point for concatinating the data

# %%
# Process files and combine
from pathlib import Path
DATA_DIR = 'data/'
PATTERN = '*.csv'

for file in Path(DATA_DIR).glob(PATTERN):
    print(f"Processing file: {file}")
# Out:
# Processing file: data\report1.csv
# Processing file: data\report2.csv
# Processing file: data\report3.csv
# Processing file: data\report4.csv
# Processing file: data\report5.csv
# Processing file: data\report6.csv
# Processing file: data\report7.csv

# %%
# df = pd.read_csv(file, index_col=None, header=0)
data = [pd.read_csv(file, index_col=None, header=0) 
        for file in Path(DATA_DIR).glob(PATTERN)]

combined = pd.concat(data, axis=0, ignore_index=True)

# %%
result = combined
result.to_csv("results/output.csv", index=False)

result["date"] = pd.to_datetime(result["date"])

by_product = pd.pivot_table(result, index=["item", "size"], values=["qty"], aggfunc=sum)
by_country = pd.pivot_table(result, index=["country"], values=["qty"], aggfunc=sum)

by_product.to_csv("results/byproduct.csv")
by_country.to_csv("results/bycountry.csv")


report1 = pd.read_csv("data/report1.csv")

report1.head()
# now, we have us a standard pandas dataframe (df is just a conventional name)

# if we wanted to suppress the output, we can with a semicolon:
report1.drop("order_id", axis=1);

report1.head()

report1.info()
x_data = report1['qty']



# report 2 results 
report2 = pd.read_csv("data/report2.csv")

report2.head()
# now, we have us a standard pandas dataframe (df is just a conventional name)

# if we wanted to suppress the output, we can with a semicolon:
report2.drop("order_id", axis=1);

report2.head()

report2.info()
y_data = report2['qty']
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    1000 non-null   str
#  1   date        1000 non-null   str
#  2   email       1000 non-null   str
#  3   first_name  1000 non-null   str
#  4   last_name   1000 non-null   str
#  5   address     1000 non-null   str
#  6   country     1000 non-null   str
#  7   item        1000 non-null   str
#  8   size        1000 non-null   str
#  9   qty         1000 non-null   int64
# dtypes: int64(1), str(9)
# memory usage: 182.3 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    1000 non-null   str
#  1   date        1000 non-null   str
#  2   email       1000 non-null   str
#  3   first_name  1000 non-null   str
#  4   last_name   1000 non-null   str
#  5   address     1000 non-null   str
#  6   country     1000 non-null   str
#  7   item        1000 non-null   str
#  8   size        1000 non-null   str
#  9   qty         1000 non-null   int64
# dtypes: int64(1), str(9)
# memory usage: 182.4 KB

# %% [markdown]
# ### --- End of notebook ---
